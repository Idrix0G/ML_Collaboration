# %%
import pandas as pd
import seaborn as sns
import numpy as np
import sklearn.linear_model  as lr
import sklearn.model_selection as train_test_split
import matplotlib.pyplot as plt

data = pd.read_excel('02 Churn-Dataset.xlsx')
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No              No  Month-to-month              Yes
# 1             No              No        One year               No
# 2             No              No  Month-to-month              Yes
# 3             No              No        One year               No
# 4             No              No  Month-to-month              Yes
# ...          ...             ...             ...              ...
# 7038         Yes             Yes        One year              Yes
# 7039         Yes             Yes        One year              Yes
# 7040          No              No  Month-to-month              Yes
# 7041          No              No  Month-to-month              Yes
# 7042         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges numAdminTickets  \
# 0              Electronic check          29.85        29.85               0
# 1                  Mailed check          56.95       1889.5               0
# 2                  Mailed check          53.85       108.15               0
# 3     Bank transfer (automatic)          42.30      1840.75               0
# 4              Electronic check          70.70       151.65               0
# ...                         ...            ...          ...             ...
# 7038               Mailed check          84.80       1990.5               0
# 7039    Credit card (automatic)         103.20       7362.9               0
# 7040           Electronic check          29.60       346.45               0
# 7041               Mailed check          74.40        306.6               0
# 7042  Bank transfer (automatic)         105.65       6844.5               2
#
#       numTechTickets Churn
# 0                  0    No
# 1                  0    No
# 2                  0   Yes
# 3                  3    No
# 4                  0   Yes
# ...              ...   ...
# 7038               0    No
# 7039               5    No
# 7040               0    No
# 7041               0   Yes
# 7042               0    No
#
# [7043 rows x 23 columns]

# %%
record = data

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No              No  Month-to-month              Yes
# 1             No              No        One year               No
# 2             No              No  Month-to-month              Yes
# 3             No              No        One year               No
# 4             No              No  Month-to-month              Yes
# ...          ...             ...             ...              ...
# 7038         Yes             Yes        One year              Yes
# 7039         Yes             Yes        One year              Yes
# 7040          No              No  Month-to-month              Yes
# 7041          No              No  Month-to-month              Yes
# 7042         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges numAdminTickets  \
# 0              Electronic check          29.85        29.85               0
# 1                  Mailed check          56.95       1889.5               0
# 2                  Mailed check          53.85       108.15               0
# 3     Bank transfer (automatic)          42.30      1840.75               0
# 4              Electronic check          70.70       151.65               0
# ...                         ...            ...          ...             ...
# 7038               Mailed check          84.80       1990.5               0
# 7039    Credit card (automatic)         103.20       7362.9               0
# 7040           Electronic check          29.60       346.45               0
# 7041               Mailed check          74.40        306.6               0
# 7042  Bank transfer (automatic)         105.65       6844.5               2
#
#       numTechTickets Churn
# 0                  0    No
# 1                  0    No
# 2                  0   Yes
# 3                  3    No
# 4                  0   Yes
# ...              ...   ...
# 7038               0    No
# 7039               5    No
# 7040               0    No
# 7041               0   Yes
# 7042               0    No
#
# [7043 rows x 23 columns]

# %%
serv_stats = data.MonthlyCharges('Contract')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...          No
# 4                No     Fiber optic             No  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# 0              No  Month-to-month              Yes           Electronic check
# 1              No        One year               No               Mailed check
# 2              No  Month-to-month              Yes               Mailed check
# 3              No        One year               No  Bank transfer (automatic)
# 4              No  Month-to-month              Yes           Electronic check
#
#   MonthlyCharges TotalCharges numAdminTickets  numTechTickets Churn
# 0          29.85        29.85               0               0    No
# 1          56.95       1889.5               0               0    No
# 2          53.85       108.15               0               0   Yes
# 3          42.30      1840.75               0               3    No
# 4          70.70       151.65               0               0   Yes
#
# [5 rows x 23 columns]

# %%
# Initialize a grid of plots with an Axes for each walk
grid = sns.FacetGrid(data, col="MonthlyCharges", hue="PhoneService", palette="tab20c",
                     col_wrap=4, height=1.5)

# Draw a horizontal line to show the starting point
grid.refline(y=0, linestyle=":")

# Draw a line plot to show the trajectory of each random walk
grid.map(plt.plot, "MonthlyCharges", "PhoneService", marker="o")

# Adjust the tick positions and labels
grid.set(xticks=np.arange(5), yticks=[-3, 3],
         xlim=(-.5, 4.5), ylim=(-3.5, 3.5))

# Adjust the arrangement of the plots
grid.fig.tight_layout(w_pad=1)

# %%
from sklearn.preprocessing import LabelEncoder

lenc = LabelEncoder()
data['gender']=lenc.fit_transform(data['gender'])
data['Partner']=lenc.fit_transform(data['Partner'])
data['Dependents']=lenc.fit_transform(data['Dependents'])
data['PhoneService']=lenc.fit_transform(data['PhoneService'])
data['MultipleLines']=lenc.fit_transform(data['MultipleLines'])
data['InternetService']=lenc.fit_transform(data['InternetService'])
data['OnlineSecurity']=lenc.fit_transform(data['OnlineSecurity'])
data['StreamingTV']=lenc.fit_transform(data['StreamingTV'])
data['Contract']=lenc.fit_transform(data['Contract'])
data['PaperlessBilling']=lenc.fit_transform(data['PaperlessBilling'])
data['PaymentMethod']=lenc.fit_transform(data['PaymentMethod'])
data['Churn']=lenc.fit_transform(data['Churn'])
data['OnlineBackup']=lenc.fit_transform(data['OnlineBackup'])
data['StreamingMovies']=lenc.fit_transform(data['StreamingMovies'])
data['DeviceProtection']=lenc.fit_transform(data['DeviceProtection'])
data['TechSupport']=lenc.fit_transform(data['TechSupport'])

data
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        1           0       1
# 1     5575-GNVDE       1              0        0           0      34
# 2     3668-QPYBK       1              0        0           0       2
# 3     7795-CFOCW       1              0        0           0      45
# 4     9237-HQITU       0              0        0           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       1              0        1           1      24
# 7039  2234-XADUH       0              0        1           1      72
# 7040  4801-JZAZL       0              0        1           1      11
# 7041  8361-LTMKD       1              1        1           0       4
# 7042  3186-AJIEK       1              0        0           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0                0              1                0               0  ...
# 1                1              0                0               2  ...
# 2                1              0                0               2  ...
# 3                0              1                0               2  ...
# 4                1              0                1               0  ...
# ...            ...            ...              ...             ...  ...
# 7038             1              2                0               2  ...
# 7039             1              2                1               0  ...
# 7040             0              1                0               2  ...
# 7041             1              2                1               0  ...
# 7042             1              0                1               2  ...
#
#       StreamingTV  StreamingMovies  Contract  PaperlessBilling  PaymentMethod  \
# 0               0                0         0                 1              2
# 1               0                0         1                 0              3
# 2               0                0         0                 1              3
# 3               0                0         1                 0              0
# 4               0                0         0                 1              2
# ...           ...              ...       ...               ...            ...
# 7038            2                2         1                 1              3
# 7039            2                2         1                 1              1
# 7040            0                0         0                 1              2
# 7041            0                0         0                 1              3
# 7042            2                2         2                 1              0
#
#       MonthlyCharges  TotalCharges  numAdminTickets  numTechTickets Churn
# 0              29.85         29.85                0               0     0
# 1              56.95        1889.5                0               0     0
# 2              53.85        108.15                0               0     1
# 3              42.30       1840.75                0               3     0
# 4              70.70        151.65                0               0     1
# ...              ...           ...              ...             ...   ...
# 7038           84.80        1990.5                0               0     0
# 7039          103.20        7362.9                0               5     0
# 7040           29.60        346.45                0               0     0
# 7041           74.40         306.6                0               0     1
# 7042          105.65        6844.5                2               0     0
#
# [7043 rows x 23 columns]

# %%
from scipy import stats

corr_df = pd.DataFrame(columns=['r', 'P-value'])

for col in data:
    if pd.api.types.is_numeric_dtype(data[col]):
        r , p = stats.pearsonr(data.Churn, data[col])
        corr_df.loc[col] = [round(r, 4), round(p, 4)]
    
corr_df
# Out:
#                        r  P-value
# gender           -0.0086   0.4699
# SeniorCitizen     0.1509   0.0000
# Partner          -0.1504   0.0000
# Dependents       -0.1642   0.0000
# tenure           -0.3522   0.0000
# PhoneService      0.0119   0.3163
# MultipleLines     0.0380   0.0014
# InternetService  -0.0473   0.0001
# OnlineSecurity   -0.2893   0.0000
# OnlineBackup     -0.1955   0.0000
# DeviceProtection -0.1781   0.0000
# TechSupport      -0.2825   0.0000
# StreamingTV      -0.0366   0.0021
# StreamingMovies  -0.0385   0.0012
# Contract         -0.3967   0.0000
# PaperlessBilling  0.1918   0.0000
# PaymentMethod     0.1071   0.0000
# MonthlyCharges    0.1934   0.0000
# numAdminTickets  -0.0199   0.0953
# numTechTickets    0.3573   0.0000
# Churn             1.0000   0.0000

# %%
y = data.Churn
x = data.drop(['customerID','numAdminTickets','TotalCharges','PhoneService','gender','Churn'], axis='columns')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size= 0.2, random_state=42)

from sklearn import linear_model as lr 
train_model = lr.LogisticRegression(max_iter=7043).fit(x_train, y_train)

# %%
lr_score = train_model.score(x_test,y_test)
print(f"Model accuracy: {lr_score}")
print(f"intercept: {train_model.intercept_}")    
print(f"slope: {train_model.coef_}")
# Out:
# Model accuracy: 0.8601845280340668
# intercept: [-0.37470809]
# slope: [[ 0.29668572  0.05656917 -0.12545401 -0.07882456  0.17180353  0.14533101
#   -0.38187197 -0.25212916 -0.16629653 -0.22491289 -0.07220459 -0.047323
#   -1.12230383  0.32177428 -0.02888138  0.01512116  1.40956819]]

# %%
from sklearn.metrics import confusion_matrix

y_prediction = train_model.predict(x_test)
y_actual = y_test
cm = confusion_matrix(y_actual, y_prediction)

# heatmap visulization of confusion matrix
f, ax = plt.subplots(figsize =(7, 7))
sns.heatmap(cm, cmap='Greens', annot = True, linewidth=1, linecolor="red", fmt =".0f", ax=ax)
plt.xlabel("prediction")
plt.ylabel("actual")
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import GaussianNB

name =  ["Nearest Neighbor","Random Forest", "Polymomial SVM", "Decision Tree","AdaBoost", "Naive bayes"]

algorithm = [
    KNeighborsClassifier(3),
    RandomForestClassifier(max_depth=5, n_estimators=100),
    SVC(kernel="linear", C=0.025),
    DecisionTreeClassifier(max_depth=5),
    AdaBoostClassifier(n_estimators=100),
    GaussianNB()]

# %%
#df = pd.DataFrame(columns=['Test Algorithm','Model Score'], dtype=object)
#scores = []
#for name, algorithm in zip (name, algorithm):
    #algorithm.fit(x_train, y_train)
   # score = algorithm.score(x_test, y_test)
    #scores.append(score)
    #df.loc[col] = [name,scores]
#df

# %%
#df = pd.DataFrame(columns=['Test Algorithm','Model Score'], dtype=object)
scores = []
for algorithm in (algorithm):
    algorithm.fit(x_train, y_train)
    score = algorithm.score(x_test, y_test)
    scores.append(score)
    #df.loc[col] = [name,scores]
scores
# Out:
# [0.8268275372604684,
#  0.8608942512420156,
#  0.8644428672817601,
#  0.8537970191625266,
#  0.8601845280340668,
#  0.8168914123491838]

# %%
df = pd.DataFrame()
df['Classifier'] = name
df['Accuracy Score'] = scores
df
# Out:
#          Classifier  Accuracy Score
# 0  Nearest Neighbor        0.826828
# 1     Random Forest        0.860894
# 2    Polymomial SVM        0.864443
# 3     Decision Tree        0.853797
# 4          AdaBoost        0.860185
# 5       Naive bayes        0.816891

# %%
cm = sns.light_palette('green', as_cmap=True)
s = df.style.background_gradient(cmap=cm)
s
# Out:
# <style type="text/css">
# #T_f4495_row0_col1 {
#   background-color: #badbba;
#   color: #000000;
# }
# #T_f4495_row1_col1 {
#   background-color: #118911;
#   color: #f1f1f1;
# }
# #T_f4495_row2_col1 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# #T_f4495_row3_col1 {
#   background-color: #349a34;
#   color: #f1f1f1;
# }
# #T_f4495_row4_col1 {
#   background-color: #148a14;
#   color: #f1f1f1;
# }
# #T_f4495_row5_col1 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# </style>
# <table id="T_f4495">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4495_level0_col0" class="col_heading level0 col0" >Classifier</th>
#       <th id="T_f4495_level0_col1" class="col_heading level0 col1" >Accuracy Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4495_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4495_row0_col0" class="data row0 col0" >Nearest Neighbor</td>
#       <td id="T_f4495_row0_col1" class="data row0 col1" >0.826828</td>
#     </tr>
#     <tr>
#       <th id="T_f4495_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4495_row1_col0" class="data row1 col0" >Random Forest</td>
#       <td id="T_f4495_row1_col1" class="data row1 col1" >0.860894</td>
#     </tr>
#     <tr>
#       <th id="T_f4495_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f4495_row2_col0" class="data row2 col0" >Polymomial SVM</td>
#       <td id="T_f4495_row2_col1" class="data row2 col1" >0.864443</td>
#     </tr>
#     <tr>
#       <th id="T_f4495_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f4495_row3_col0" class="data row3 col0" >Decision Tree</td>
#       <td id="T_f4495_row3_col1" class="data row3 col1" >0.853797</td>
#     </tr>
#     <tr>
#       <th id="T_f4495_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f4495_row4_col0" class="data row4 col0" >AdaBoost</td>
#       <td id="T_f4495_row4_col1" class="data row4 col1" >0.860185</td>
#     </tr>
#     <tr>
#       <th id="T_f4495_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f4495_row5_col0" class="data row5 col0" >Naive bayes</td>
#       <td id="T_f4495_row5_col1" class="data row5 col1" >0.816891</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.set(style='whitegrid')
ax = sns.barplot(y='Classifier', x='Accuracy Score', data=df)
